# %% [markdown]
# ## EXPLORATION DATA ANALYSIS (EDA)

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
# load data
df1 = pd.read_csv("../data/climate-daily-st_johns.csv")
print(f"data 1 shape: {df1.shape}")
df2 = pd.read_csv("../data/climate-daily-mount_pearl.csv")
print(f"data 1 shape: {df2.shape}")

df_concat = pd.concat([df1, df2], ignore_index=True)
print(f"\nMerged dataset shape: {df_concat.shape}")
df_concat.head()
# Out:
# data 1 shape: (3865, 36)
# data 1 shape: (5568, 36)
#
# Merged dataset shape: (9433, 36)
#            x          y STATION_NAME  CLIMATE_IDENTIFIER                ID  \
# 0 -52.742778  47.622222  ST JOHN'S A             8403506  8403506.2000.1.1
# 1 -52.742778  47.622222  ST JOHN'S A             8403506  8403506.2000.1.2
# 2 -52.742778  47.622222  ST JOHN'S A             8403506  8403506.2000.1.3
# 3 -52.742778  47.622222  ST JOHN'S A             8403506  8403506.2000.1.4
# 4 -52.742778  47.622222  ST JOHN'S A             8403506  8403506.2000.1.5
#
#             LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY  ...  \
# 0  2000-01-01 00:00:00            NL        2000            1          1  ...
# 1  2000-01-02 00:00:00            NL        2000            1          2  ...
# 2  2000-01-03 00:00:00            NL        2000            1          3  ...
# 3  2000-01-04 00:00:00            NL        2000            1          4  ...
# 4  2000-01-05 00:00:00            NL        2000            1          5  ...
#
#    SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  COOLING_DEGREE_DAYS  \
# 0             0.0                 NaN                  0.0
# 1            59.0                   E                  0.0
# 2            78.0                   E                  0.0
# 3            78.0                   E                  0.0
# 4            93.0                   E                  0.0
#
#   COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS HEATING_DEGREE_DAYS_FLAG  \
# 0                      NaN                 26.3                      NaN
# 1                      NaN                 21.9                      NaN
# 2                      NaN                 19.1                      NaN
# 3                      NaN                 22.6                      NaN
# 4                      NaN                 10.8                      NaN
#
#    MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  MAX_REL_HUMIDITY  \
# 0               NaN                     M               NaN
# 1               NaN                     M               NaN
# 2               NaN                     M               NaN
# 3               NaN                     M               NaN
# 4               NaN                     M               NaN
#
#   MAX_REL_HUMIDITY_FLAG
# 0                     M
# 1                     M
# 2                     M
# 3                     M
# 4                     M
#
# [5 rows x 36 columns]

# %%
df_merge.tail()
# Out:
#                x          y STATION_NAME  CLIMATE_IDENTIFIER  \
# 28015 -52.683333  47.566667  SIGNAL HILL             8403669
# 28016 -52.683333  47.566667  SIGNAL HILL             8403669
# 28017 -52.683333  47.566667  SIGNAL HILL             8403669
# 28018 -52.683333  47.566667  SIGNAL HILL             8403669
# 28019 -52.683333  47.566667  SIGNAL HILL             8403669
#
#                        ID           LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  \
# 28015  8403669.1999.12.27  1999-12-27 00:00:00            NL        1999
# 28016  8403669.1999.12.28  1999-12-28 00:00:00            NL        1999
# 28017  8403669.1999.12.29  1999-12-29 00:00:00            NL        1999
# 28018  8403669.1999.12.30  1999-12-30 00:00:00            NL        1999
# 28019  8403669.1999.12.31  1999-12-31 00:00:00            NL        1999
#
#        LOCAL_MONTH  LOCAL_DAY  ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  \
# 28015           12         27  ...             NaN                 NaN
# 28016           12         28  ...             NaN                 NaN
# 28017           12         29  ...             NaN                 NaN
# 28018           12         30  ...             NaN                 NaN
# 28019           12         31  ...             NaN                 NaN
#
#        COOLING_DEGREE_DAYS COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS  \
# 28015                  0.0                      NaN                 18.5
# 28016                  0.0                      NaN                 19.8
# 28017                  0.0                      NaN                 21.5
# 28018                  0.0                      NaN                 20.5
# 28019                  0.0                      NaN                 23.0
#
#       HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  \
# 28015                      NaN               NaN                   NaN
# 28016                      NaN               NaN                   NaN
# 28017                      NaN               NaN                   NaN
# 28018                      NaN               NaN                   NaN
# 28019                      NaN               NaN                   NaN
#
#        MAX_REL_HUMIDITY MAX_REL_HUMIDITY_FLAG
# 28015               NaN                   NaN
# 28016               NaN                   NaN
# 28017               NaN                   NaN
# 28018               NaN                   NaN
# 28019               NaN                   NaN
#
# [5 rows x 36 columns]

# %%
# dataset info
print(df_merge.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28020 entries, 0 to 28019
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   x                         28020 non-null  float64
#  1   y                         28020 non-null  float64
#  2   STATION_NAME              28020 non-null  object
#  3   CLIMATE_IDENTIFIER        28020 non-null  int64
#  4   ID                        28020 non-null  object
#  5   LOCAL_DATE                28020 non-null  object
#  6   PROVINCE_CODE             28020 non-null  object
#  7   LOCAL_YEAR                28020 non-null  int64
#  8   LOCAL_MONTH               28020 non-null  int64
#  9   LOCAL_DAY                 28020 non-null  int64
#  10  MEAN_TEMPERATURE          27185 non-null  float64
#  11  MEAN_TEMPERATURE_FLAG     1061 non-null   object
#  12  MIN_TEMPERATURE           27287 non-null  float64
#  13  MIN_TEMPERATURE_FLAG      1109 non-null   object
#  14  MAX_TEMPERATURE           27487 non-null  float64
#  15  MAX_TEMPERATURE_FLAG      782 non-null    object
#  16  TOTAL_PRECIPITATION       27128 non-null  float64
#  17  TOTAL_PRECIPITATION_FLAG  3057 non-null   object
#  18  TOTAL_RAIN                18099 non-null  float64
#  19  TOTAL_RAIN_FLAG           4022 non-null   object
#  20  TOTAL_SNOW                18165 non-null  float64
#  21  TOTAL_SNOW_FLAG           3907 non-null   object
#  22  SNOW_ON_GROUND            13750 non-null  float64
#  23  SNOW_ON_GROUND_FLAG       2361 non-null   object
#  24  DIRECTION_MAX_GUST        4900 non-null   float64
#  25  DIRECTION_MAX_GUST_FLAG   126 non-null    object
#  26  SPEED_MAX_GUST            4908 non-null   float64
#  27  SPEED_MAX_GUST_FLAG       120 non-null    object
#  28  COOLING_DEGREE_DAYS       27185 non-null  float64
#  29  COOLING_DEGREE_DAYS_FLAG  1061 non-null   object
#  30  HEATING_DEGREE_DAYS       27185 non-null  float64
#  31  HEATING_DEGREE_DAYS_FLAG  1061 non-null   object
#  32  MIN_REL_HUMIDITY          3767 non-null   float64
#  33  MIN_REL_HUMIDITY_FLAG     112 non-null    object
#  34  MAX_REL_HUMIDITY          3765 non-null   float64
#  35  MAX_REL_HUMIDITY_FLAG     114 non-null    object
# dtypes: float64(15), int64(4), object(17)
# memory usage: 7.7+ MB
# None

# %%
# unique values
df_merge.nunique()
# Out:
# x                               4
# y                               4
# STATION_NAME                    4
# CLIMATE_IDENTIFIER              4
# ID                          28020
# LOCAL_DATE                  19038
# PROVINCE_CODE                   1
# LOCAL_YEAR                     55
# LOCAL_MONTH                    12
# LOCAL_DAY                      31
# MEAN_TEMPERATURE              416
# MEAN_TEMPERATURE_FLAG           2
# MIN_TEMPERATURE               415
# MIN_TEMPERATURE_FLAG            4
# MAX_TEMPERATURE               435
# MAX_TEMPERATURE_FLAG            2
# TOTAL_PRECIPITATION           475
# TOTAL_PRECIPITATION_FLAG        7
# TOTAL_RAIN                    364
# TOTAL_RAIN_FLAG                 7
# TOTAL_SNOW                    137
# TOTAL_SNOW_FLAG                 7
# SNOW_ON_GROUND                139
# SNOW_ON_GROUND_FLAG             3
# DIRECTION_MAX_GUST             37
# DIRECTION_MAX_GUST_FLAG         2
# SPEED_MAX_GUST                 69
# SPEED_MAX_GUST_FLAG             2
# COOLING_DEGREE_DAYS            74
# COOLING_DEGREE_DAYS_FLAG        2
# HEATING_DEGREE_DAYS           343
# HEATING_DEGREE_DAYS_FLAG        2
# MIN_REL_HUMIDITY               83
# MIN_REL_HUMIDITY_FLAG           1
# MAX_REL_HUMIDITY               38
# MAX_REL_HUMIDITY_FLAG           1
# dtype: int64

# %%
df_merge['LOCAL_DATE_dt'] = pd.to_datetime(
    df_merge['LOCAL_DATE'], errors='coerce')
df_merge[["LOCAL_DATE_dt", "LOCAL_DATE"]]
# Out:
#       LOCAL_DATE_dt           LOCAL_DATE
# 0        2000-03-01  2000-03-01 00:00:00
# 1        2000-03-02  2000-03-02 00:00:00
# 2        2000-03-03  2000-03-03 00:00:00
# 3        2000-03-04  2000-03-04 00:00:00
# 4        2000-03-05  2000-03-05 00:00:00
# ...             ...                  ...
# 28015    1999-12-27  1999-12-27 00:00:00
# 28016    1999-12-28  1999-12-28 00:00:00
# 28017    1999-12-29  1999-12-29 00:00:00
# 28018    1999-12-30  1999-12-30 00:00:00
# 28019    1999-12-31  1999-12-31 00:00:00
#
# [28020 rows x 2 columns]

# %%
df_merge.columns
# Out:
# Index(['x', 'y', 'STATION_NAME', 'CLIMATE_IDENTIFIER', 'ID', 'LOCAL_DATE',
#        'PROVINCE_CODE', 'LOCAL_YEAR', 'LOCAL_MONTH', 'LOCAL_DAY',
#        'MEAN_TEMPERATURE', 'MEAN_TEMPERATURE_FLAG', 'MIN_TEMPERATURE',
#        'MIN_TEMPERATURE_FLAG', 'MAX_TEMPERATURE', 'MAX_TEMPERATURE_FLAG',
#        'TOTAL_PRECIPITATION', 'TOTAL_PRECIPITATION_FLAG', 'TOTAL_RAIN',
#        'TOTAL_RAIN_FLAG', 'TOTAL_SNOW', 'TOTAL_SNOW_FLAG', 'SNOW_ON_GROUND',
#        'SNOW_ON_GROUND_FLAG', 'DIRECTION_MAX_GUST', 'DIRECTION_MAX_GUST_FLAG',
#        'SPEED_MAX_GUST', 'SPEED_MAX_GUST_FLAG', 'COOLING_DEGREE_DAYS',
#        'COOLING_DEGREE_DAYS_FLAG', 'HEATING_DEGREE_DAYS',
#        'HEATING_DEGREE_DAYS_FLAG', 'MIN_REL_HUMIDITY', 'MIN_REL_HUMIDITY_FLAG',
#        'MAX_REL_HUMIDITY', 'MAX_REL_HUMIDITY_FLAG', 'LOCAL_DATE_dt'],
#       dtype='object')

# %%
features = ['x', 'y', 'STATION_NAME', 'CLIMATE_IDENTIFIER', 'ID', 'LOCAL_DATE',
            'LOCAL_DATE_dt', 'PROVINCE_CODE', 'LOCAL_YEAR', 'LOCAL_MONTH', 'LOCAL_DAY',
            'MEAN_TEMPERATURE', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE',
            'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW', 'SNOW_ON_GROUND',
            'COOLING_DEGREE_DAYS', 'HEATING_DEGREE_DAYS',]

# %%
df_unflagged = df_merge[features]
df_unflagged.head()
# Out:
#            x          y           STATION_NAME  CLIMATE_IDENTIFIER  \
# 0 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 1 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 2 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 3 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 4 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
#
#                  ID           LOCAL_DATE LOCAL_DATE_dt PROVINCE_CODE  \
# 0  8403605.2000.3.1  2000-03-01 00:00:00    2000-03-01            NL
# 1  8403605.2000.3.2  2000-03-02 00:00:00    2000-03-02            NL
# 2  8403605.2000.3.3  2000-03-03 00:00:00    2000-03-03            NL
# 3  8403605.2000.3.4  2000-03-04 00:00:00    2000-03-04            NL
# 4  8403605.2000.3.5  2000-03-05 00:00:00    2000-03-05            NL
#
#    LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY  MEAN_TEMPERATURE  MIN_TEMPERATURE  \
# 0        2000            3          1               1.6              0.6
# 1        2000            3          2               3.8              0.1
# 2        2000            3          3               NaN              1.2
# 3        2000            3          4               NaN              NaN
# 4        2000            3          5               NaN              NaN
#
#    MAX_TEMPERATURE  TOTAL_PRECIPITATION  TOTAL_RAIN  TOTAL_SNOW  \
# 0              2.6                  0.9         NaN         NaN
# 1              7.5                  4.7         NaN         NaN
# 2              NaN                  NaN         NaN         NaN
# 3              NaN                  NaN         NaN         NaN
# 4              NaN                  NaN         NaN         NaN
#
#    SNOW_ON_GROUND  COOLING_DEGREE_DAYS  HEATING_DEGREE_DAYS
# 0             NaN                  0.0                 16.4
# 1             NaN                  0.0                 14.2
# 2             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 4             NaN                  NaN                  NaN

# %%
df_unflagged[["LOCAL_DATE_dt"]].max()
# Out:
# LOCAL_DATE_dt   2025-10-20
# dtype: datetime64[ns]

# %%
# Missing values
print(df_unflagged.isnull().sum())
# Out:
# x                          0
# y                          0
# STATION_NAME               0
# CLIMATE_IDENTIFIER         0
# ID                         0
# LOCAL_DATE                 0
# LOCAL_DATE_dt              0
# PROVINCE_CODE              0
# LOCAL_YEAR                 0
# LOCAL_MONTH                0
# LOCAL_DAY                  0
# MEAN_TEMPERATURE         835
# MIN_TEMPERATURE          733
# MAX_TEMPERATURE          533
# TOTAL_PRECIPITATION      892
# TOTAL_RAIN              9921
# TOTAL_SNOW              9855
# SNOW_ON_GROUND         14270
# COOLING_DEGREE_DAYS      835
# HEATING_DEGREE_DAYS      835
# dtype: int64

# %%
# visualize missing values
sns.heatmap(df_unflagged.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df_unflagged.shape
# Out:
# (28020, 20)

# %%
from sklearn.impute import KNNImputer

features_to_impute = ['MEAN_TEMPERATURE',
                      'MIN_TEMPERATURE',
                      'MAX_TEMPERATURE',
                      'TOTAL_PRECIPITATION',
                      'TOTAL_RAIN',
                      'TOTAL_SNOW',
                      'SNOW_ON_GROUND',
                      'COOLING_DEGREE_DAYS',
                      'HEATING_DEGREE_DAYS']

features_existing = [
    f for f in features_to_impute
    if f in df_unflagged.columns and pd.api.types.is_numeric_dtype(df_unflagged[f])
]

print(f"Imputing {len(features_existing)} numeric columns:")
print(features_existing)

# Extract only features
data = df_unflagged[features_existing].values

if data.dtype == 'object':
    raise ValueError("Data still contains non-numeric values!")

# Initialize and Impute data
imputer = KNNImputer(n_neighbors=5, weights='distance')
data_imputed = imputer.fit_transform(data)

# replace in main data
df_imputed = df_unflagged.copy()
df_imputed[features_existing] = pd.DataFrame(
    data_imputed,
    columns=features_existing,
    index=df_unflagged.index
)
# Out:
# Imputing 9 numeric columns:
# ['MEAN_TEMPERATURE', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW', 'SNOW_ON_GROUND', 'COOLING_DEGREE_DAYS', 'HEATING_DEGREE_DAYS']

# %%
print(features)
# Out:
# ['x', 'y', 'STATION_NAME', 'CLIMATE_IDENTIFIER', 'ID', 'LOCAL_DATE', 'LOCAL_DATE_dt', 'PROVINCE_CODE', 'LOCAL_YEAR', 'LOCAL_MONTH', 'LOCAL_DAY', 'MEAN_TEMPERATURE', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW', 'SNOW_ON_GROUND', 'COOLING_DEGREE_DAYS', 'HEATING_DEGREE_DAYS']

# %%
# visualize missing values
sns.heatmap(df_imputed.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# data exploration
print(df_imputed.describe())
# Out:
#                   x             y  CLIMATE_IDENTIFIER  \
# count  28020.000000  28020.000000        2.802000e+04
# mean     -52.709289     47.574265        8.403158e+06
# min      -52.784722     47.513356        8.402568e+06
# 25%      -52.783339     47.515556        8.402568e+06
# 50%      -52.683333     47.566667        8.403603e+06
# 75%      -52.664167     47.624167        8.403605e+06
# max      -52.664167     47.624167        8.403669e+06
# std        0.054382      0.048495        5.276477e+02
#
#                        LOCAL_DATE_dt    LOCAL_YEAR   LOCAL_MONTH  \
# count                          28020  28020.000000  28020.000000
# mean   1996-09-19 16:32:53.447537408   1996.217452      6.548001
# min              1969-12-01 00:00:00   1969.000000      1.000000
# 25%              1987-02-02 00:00:00   1987.000000      4.000000
# 50%              1996-06-24 00:00:00   1996.000000      7.000000
# 75%              2004-03-22 00:00:00   2004.000000     10.000000
# max              2025-10-20 00:00:00   2025.000000     12.000000
# std                              NaN     13.873854      3.440232
#
#           LOCAL_DAY  MEAN_TEMPERATURE  MIN_TEMPERATURE  MAX_TEMPERATURE  \
# count  28020.000000      28020.000000     28020.000000     28020.000000
# mean      15.731799          5.697817         1.802819         9.572882
# min        1.000000        -19.500000       -26.000000       -17.800000
# 25%        8.000000         -0.300000        -3.000000         2.600000
# 50%       16.000000          5.000000         1.500000         9.000000
# 75%       23.000000         12.000000         7.700000        16.500000
# max       31.000000         26.800000        28.300000        31.800000
# std        8.801651          8.022601         7.731350         8.763055
#
#        TOTAL_PRECIPITATION    TOTAL_RAIN    TOTAL_SNOW  SNOW_ON_GROUND  \
# count         28020.000000  28020.000000  28020.000000    28020.000000
# mean              3.395558      2.690238      0.461658        5.384335
# min               0.000000      0.000000      0.000000        0.000000
# 25%               0.000000      0.000000      0.000000        0.000000
# 50%               0.000000      0.000000      0.000000        0.000000
# 75%               3.300000      2.000000      0.000000        1.143879
# max             106.300000     93.000000     70.000000      175.000000
# std               7.210530      6.285192      2.239563       14.403099
#
#        COOLING_DEGREE_DAYS  HEATING_DEGREE_DAYS
# count         28020.000000         28020.000000
# mean              0.142088            12.444271
# min               0.000000             0.000000
# 25%               0.000000             6.000000
# 50%               0.000000            13.000000
# 75%               0.000000            18.300000
# max               8.800000            37.500000
# std               0.652847             7.772739

# %%
print(df_imputed.LOCAL_YEAR.max())
print(df_imputed.LOCAL_YEAR.min())
# Out:
# 2025
# 1969

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_imputed, x='LOCAL_YEAR', y='MEAN_TEMPERATURE')
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')

plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../plots/mean_temp_over_time.png", dpi=300)
plt.show()

# %%
df_unflagged["STATION_NAME"].unique()
# Out:
# array(["ST JOHN'S WEST CDA CS", 'ST JOHNS WEST CLIMATE', 'LOGY BAY',
#        'SIGNAL HILL'], dtype=object)

# %%
df_imputed.to_csv("../data/climate-daily-complete.csv", index=False)
