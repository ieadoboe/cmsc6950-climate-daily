# %% [markdown]
# ## EXPLORATION DATA ANALYSIS (EDA)

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df1 = pd.read_csv("climate-daily-1.csv")
print(df1.shape)
df2 = pd.read_csv("climate-daily-2.csv")
print(df2.shape)
# df_merge = pd.merge(df1, df2, on='y', how='left')
df_merge = pd.concat([df1, df2], ignore_index=True)
print(df_merge.shape)
df_merge.head()
# Out:
# (10000, 36)
# (216, 36)
# (10216, 36)
#            x          y           STATION_NAME  CLIMATE_IDENTIFIER  \
# 0 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 1 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 2 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 3 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 4 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
#
#                  ID           LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  \
# 0  8403605.2000.3.1  2000-03-01 00:00:00            NL        2000
# 1  8403605.2000.3.2  2000-03-02 00:00:00            NL        2000
# 2  8403605.2000.3.3  2000-03-03 00:00:00            NL        2000
# 3  8403605.2000.3.4  2000-03-04 00:00:00            NL        2000
# 4  8403605.2000.3.5  2000-03-05 00:00:00            NL        2000
#
#    LOCAL_MONTH  LOCAL_DAY  ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  \
# 0            3          1  ...             NaN                 NaN
# 1            3          2  ...             NaN                 NaN
# 2            3          3  ...             NaN                 NaN
# 3            3          4  ...             NaN                 NaN
# 4            3          5  ...             NaN                 NaN
#
#    COOLING_DEGREE_DAYS COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS  \
# 0                  0.0                      NaN                 16.4
# 1                  0.0                      NaN                 14.2
# 2                  NaN                        M                  NaN
# 3                  NaN                        M                  NaN
# 4                  NaN                        M                  NaN
#
#   HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  \
# 0                      NaN               NaN                   NaN
# 1                      NaN               NaN                   NaN
# 2                        M               NaN                   NaN
# 3                        M               NaN                   NaN
# 4                        M               NaN                   NaN
#
#    MAX_REL_HUMIDITY MAX_REL_HUMIDITY_FLAG
# 0               NaN                   NaN
# 1               NaN                   NaN
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
#
# [5 rows x 36 columns]

# %%
df_merge.tail()
# Out:
#                x          y STATION_NAME  CLIMATE_IDENTIFIER  \
# 10211 -52.683333  47.566667  SIGNAL HILL             8403669
# 10212 -52.683333  47.566667  SIGNAL HILL             8403669
# 10213 -52.683333  47.566667  SIGNAL HILL             8403669
# 10214 -52.683333  47.566667  SIGNAL HILL             8403669
# 10215 -52.683333  47.566667  SIGNAL HILL             8403669
#
#                       ID           LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  \
# 10211  8403669.2001.1.27  2001-01-27 00:00:00            NL        2001
# 10212  8403669.2001.1.28  2001-01-28 00:00:00            NL        2001
# 10213  8403669.2001.1.29  2001-01-29 00:00:00            NL        2001
# 10214  8403669.2001.1.30  2001-01-30 00:00:00            NL        2001
# 10215  8403669.2001.1.31  2001-01-31 00:00:00            NL        2001
#
#        LOCAL_MONTH  LOCAL_DAY  ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  \
# 10211            1         27  ...             NaN                 NaN
# 10212            1         28  ...             NaN                 NaN
# 10213            1         29  ...             NaN                 NaN
# 10214            1         30  ...             NaN                 NaN
# 10215            1         31  ...             NaN                 NaN
#
#        COOLING_DEGREE_DAYS COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS  \
# 10211                  NaN                        M                  NaN
# 10212                  NaN                        M                  NaN
# 10213                  NaN                        M                  NaN
# 10214                  NaN                        M                  NaN
# 10215                  NaN                        M                  NaN
#
#       HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  \
# 10211                        M               NaN                   NaN
# 10212                        M               NaN                   NaN
# 10213                        M               NaN                   NaN
# 10214                        M               NaN                   NaN
# 10215                        M               NaN                   NaN
#
#        MAX_REL_HUMIDITY MAX_REL_HUMIDITY_FLAG
# 10211               NaN                   NaN
# 10212               NaN                   NaN
# 10213               NaN                   NaN
# 10214               NaN                   NaN
# 10215               NaN                   NaN
#
# [5 rows x 36 columns]

# %%
# dataset info
print(df_merge.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10216 entries, 0 to 10215
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   x                         10216 non-null  float64
#  1   y                         10216 non-null  float64
#  2   STATION_NAME              10216 non-null  object
#  3   CLIMATE_IDENTIFIER        10216 non-null  int64
#  4   ID                        10216 non-null  object
#  5   LOCAL_DATE                10216 non-null  object
#  6   PROVINCE_CODE             10216 non-null  object
#  7   LOCAL_YEAR                10216 non-null  int64
#  8   LOCAL_MONTH               10216 non-null  int64
#  9   LOCAL_DAY                 10216 non-null  int64
#  10  MEAN_TEMPERATURE          9894 non-null   float64
#  11  MEAN_TEMPERATURE_FLAG     443 non-null    object
#  12  MIN_TEMPERATURE           9941 non-null   float64
#  13  MIN_TEMPERATURE_FLAG      414 non-null    object
#  14  MAX_TEMPERATURE           9980 non-null   float64
#  15  MAX_TEMPERATURE_FLAG      296 non-null    object
#  16  TOTAL_PRECIPITATION       9618 non-null   float64
#  17  TOTAL_PRECIPITATION_FLAG  1382 non-null   object
#  18  TOTAL_RAIN                1903 non-null   float64
#  19  TOTAL_RAIN_FLAG           3058 non-null   object
#  20  TOTAL_SNOW                1918 non-null   float64
#  21  TOTAL_SNOW_FLAG           3036 non-null   object
#  22  SNOW_ON_GROUND            5332 non-null   float64
#  23  SNOW_ON_GROUND_FLAG       525 non-null    object
#  24  DIRECTION_MAX_GUST        4900 non-null   float64
#  25  DIRECTION_MAX_GUST_FLAG   126 non-null    object
#  26  SPEED_MAX_GUST            4908 non-null   float64
#  27  SPEED_MAX_GUST_FLAG       120 non-null    object
#  28  COOLING_DEGREE_DAYS       9894 non-null   float64
#  29  COOLING_DEGREE_DAYS_FLAG  443 non-null    object
#  30  HEATING_DEGREE_DAYS       9894 non-null   float64
#  31  HEATING_DEGREE_DAYS_FLAG  443 non-null    object
#  32  MIN_REL_HUMIDITY          3767 non-null   float64
#  33  MIN_REL_HUMIDITY_FLAG     112 non-null    object
#  34  MAX_REL_HUMIDITY          3765 non-null   float64
#  35  MAX_REL_HUMIDITY_FLAG     114 non-null    object
# dtypes: float64(15), int64(4), object(17)
# memory usage: 2.8+ MB
# None

# %%
# unique values
df_merge.nunique()
# Out:
# x                               4
# y                               4
# STATION_NAME                    4
# CLIMATE_IDENTIFIER              4
# ID                          10216
# LOCAL_DATE                   8234
# PROVINCE_CODE                   1
# LOCAL_YEAR                     24
# LOCAL_MONTH                    12
# LOCAL_DAY                      31
# MEAN_TEMPERATURE              390
# MEAN_TEMPERATURE_FLAG           2
# MIN_TEMPERATURE               399
# MIN_TEMPERATURE_FLAG            4
# MAX_TEMPERATURE               417
# MAX_TEMPERATURE_FLAG            2
# TOTAL_PRECIPITATION           415
# TOTAL_PRECIPITATION_FLAG        7
# TOTAL_RAIN                    107
# TOTAL_RAIN_FLAG                 7
# TOTAL_SNOW                     18
# TOTAL_SNOW_FLAG                 7
# SNOW_ON_GROUND                135
# SNOW_ON_GROUND_FLAG             3
# DIRECTION_MAX_GUST             37
# DIRECTION_MAX_GUST_FLAG         2
# SPEED_MAX_GUST                 69
# SPEED_MAX_GUST_FLAG             2
# COOLING_DEGREE_DAYS            72
# COOLING_DEGREE_DAYS_FLAG        2
# HEATING_DEGREE_DAYS           319
# HEATING_DEGREE_DAYS_FLAG        2
# MIN_REL_HUMIDITY               83
# MIN_REL_HUMIDITY_FLAG           1
# MAX_REL_HUMIDITY               38
# MAX_REL_HUMIDITY_FLAG           1
# dtype: int64

# %%
# Missing values
print(df_merge.isnull().sum())
# Out:
# x                               0
# y                               0
# STATION_NAME                    0
# CLIMATE_IDENTIFIER              0
# ID                              0
# LOCAL_DATE                      0
# PROVINCE_CODE                   0
# LOCAL_YEAR                      0
# LOCAL_MONTH                     0
# LOCAL_DAY                       0
# MEAN_TEMPERATURE              322
# MEAN_TEMPERATURE_FLAG        9773
# MIN_TEMPERATURE               275
# MIN_TEMPERATURE_FLAG         9802
# MAX_TEMPERATURE               236
# MAX_TEMPERATURE_FLAG         9920
# TOTAL_PRECIPITATION           598
# TOTAL_PRECIPITATION_FLAG     8834
# TOTAL_RAIN                   8313
# TOTAL_RAIN_FLAG              7158
# TOTAL_SNOW                   8298
# TOTAL_SNOW_FLAG              7180
# SNOW_ON_GROUND               4884
# SNOW_ON_GROUND_FLAG          9691
# DIRECTION_MAX_GUST           5316
# DIRECTION_MAX_GUST_FLAG     10090
# SPEED_MAX_GUST               5308
# SPEED_MAX_GUST_FLAG         10096
# COOLING_DEGREE_DAYS           322
# COOLING_DEGREE_DAYS_FLAG     9773
# HEATING_DEGREE_DAYS           322
# HEATING_DEGREE_DAYS_FLAG     9773
# MIN_REL_HUMIDITY             6449
# MIN_REL_HUMIDITY_FLAG       10104
# MAX_REL_HUMIDITY             6451
# MAX_REL_HUMIDITY_FLAG       10102
# dtype: int64

# %%
# visualize missing values
sns.heatmap(df_merge.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df_merge.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_merge.dtypes
# Out:
# x                           float64
# y                           float64
# STATION_NAME                 object
# CLIMATE_IDENTIFIER            int64
# ID                           object
# LOCAL_DATE                   object
# PROVINCE_CODE                object
# LOCAL_YEAR                    int64
# LOCAL_MONTH                   int64
# LOCAL_DAY                     int64
# MEAN_TEMPERATURE            float64
# MEAN_TEMPERATURE_FLAG        object
# MIN_TEMPERATURE             float64
# MIN_TEMPERATURE_FLAG         object
# MAX_TEMPERATURE             float64
# MAX_TEMPERATURE_FLAG         object
# TOTAL_PRECIPITATION         float64
# TOTAL_PRECIPITATION_FLAG     object
# TOTAL_RAIN                  float64
# TOTAL_RAIN_FLAG              object
# TOTAL_SNOW                  float64
# TOTAL_SNOW_FLAG              object
# SNOW_ON_GROUND              float64
# SNOW_ON_GROUND_FLAG          object
# DIRECTION_MAX_GUST          float64
# DIRECTION_MAX_GUST_FLAG      object
# SPEED_MAX_GUST              float64
# SPEED_MAX_GUST_FLAG          object
# COOLING_DEGREE_DAYS         float64
# COOLING_DEGREE_DAYS_FLAG     object
# HEATING_DEGREE_DAYS         float64
# HEATING_DEGREE_DAYS_FLAG     object
# MIN_REL_HUMIDITY            float64
# MIN_REL_HUMIDITY_FLAG        object
# MAX_REL_HUMIDITY            float64
# MAX_REL_HUMIDITY_FLAG        object
# dtype: object

# %%
df_merge['LOCAL_DATE_conv'] = pd.to_datetime(df_merge['LOCAL_DATE'], errors='coerce')
df_merge[["LOCAL_DATE_conv", "LOCAL_DATE"]]
# Out:
#       LOCAL_DATE_conv           LOCAL_DATE
# 0          2000-03-01  2000-03-01 00:00:00
# 1          2000-03-02  2000-03-02 00:00:00
# 2          2000-03-03  2000-03-03 00:00:00
# 3          2000-03-04  2000-03-04 00:00:00
# 4          2000-03-05  2000-03-05 00:00:00
# ...               ...                  ...
# 10211      2001-01-27  2001-01-27 00:00:00
# 10212      2001-01-28  2001-01-28 00:00:00
# 10213      2001-01-29  2001-01-29 00:00:00
# 10214      2001-01-30  2001-01-30 00:00:00
# 10215      2001-01-31  2001-01-31 00:00:00
#
# [10216 rows x 2 columns]

# %%
df_clean = df_merge.dropna(axis=1, how='all') # drop all nan columns
df_clean = df_clean.loc[:, ~df_clean.columns.str.endswith('_FLAG')] # drop all columns that end in _FLAG

# %%
# visualize missing values
sns.heatmap(df_clean.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df_clean = df_clean.fillna(df.mean(numeric_only=True))
df_clean.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df_clean.shape
# Out:
# (10216, 24)

# %%
sns.heatmap(df_clean.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10216 entries, 0 to 10215
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   x                    10216 non-null  float64
#  1   y                    10216 non-null  float64
#  2   STATION_NAME         10216 non-null  object
#  3   CLIMATE_IDENTIFIER   10216 non-null  int64
#  4   ID                   10216 non-null  object
#  5   LOCAL_DATE           10216 non-null  object
#  6   PROVINCE_CODE        10216 non-null  object
#  7   LOCAL_YEAR           10216 non-null  int64
#  8   LOCAL_MONTH          10216 non-null  int64
#  9   LOCAL_DAY            10216 non-null  int64
#  10  MEAN_TEMPERATURE     10216 non-null  float64
#  11  MIN_TEMPERATURE      10216 non-null  float64
#  12  MAX_TEMPERATURE      10216 non-null  float64
#  13  TOTAL_PRECIPITATION  10216 non-null  float64
#  14  TOTAL_RAIN           10216 non-null  float64
#  15  TOTAL_SNOW           10216 non-null  float64
#  16  SNOW_ON_GROUND       10216 non-null  float64
#  17  DIRECTION_MAX_GUST   10216 non-null  float64
#  18  SPEED_MAX_GUST       10216 non-null  float64
#  19  COOLING_DEGREE_DAYS  10216 non-null  float64
#  20  HEATING_DEGREE_DAYS  10216 non-null  float64
#  21  MIN_REL_HUMIDITY     10216 non-null  float64
#  22  MAX_REL_HUMIDITY     10216 non-null  float64
#  23  LOCAL_DATE_conv      10216 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), int64(4), object(4)
# memory usage: 1.9+ MB

# %%
# data exploration
print(df_clean.describe())
# Out:
#                   x             y  CLIMATE_IDENTIFIER    LOCAL_YEAR  \
# count  10216.000000  10216.000000        1.021600e+04  10216.000000
# mean     -52.761217     47.533540        8.403439e+06   2010.811570
# min      -52.784722     47.513356        8.402568e+06   2000.000000
# 25%      -52.784722     47.513356        8.403603e+06   2003.000000
# 50%      -52.783339     47.513356        8.403603e+06   2011.000000
# 75%      -52.783339     47.515556        8.403605e+06   2018.000000
# max      -52.664167     47.624167        8.403669e+06   2025.000000
# std        0.046131      0.040804        3.817984e+02      8.296207
#
#         LOCAL_MONTH     LOCAL_DAY  MEAN_TEMPERATURE  MIN_TEMPERATURE  \
# count  10216.000000  10216.000000      10216.000000     10216.000000
# mean       6.550215     15.736590          6.392119         2.495503
# min        1.000000      1.000000        -15.300000       -20.600000
# 25%        4.000000      8.000000          0.300000        -2.500000
# 50%        7.000000     16.000000          6.300000         2.300000
# 75%       10.000000     23.000000         12.700000         8.300000
# max       12.000000     31.000000         25.300000        22.300000
# std        3.410563      8.804252          7.993928         7.647954
#
#        MAX_TEMPERATURE  TOTAL_PRECIPITATION    TOTAL_RAIN    TOTAL_SNOW  \
# count     10216.000000         10216.000000  10216.000000  10216.000000
# mean         10.279825             3.700480      2.775875      0.447835
# min         -13.000000             0.000000      0.000000      0.000000
# 25%           3.000000             0.000000      2.766034      0.441623
# 50%          10.000000             0.500000      2.766034      0.441623
# 75%          17.300000             3.691151      2.766034      0.441623
# max          31.800000           106.300000     70.000000     48.000000
# std           8.789488             7.441844      2.864954      0.997487
#
#        SNOW_ON_GROUND  DIRECTION_MAX_GUST  SPEED_MAX_GUST  \
# count    10216.000000        10216.000000    10216.000000
# mean        12.509178           19.664286       42.302567
# min          0.000000            0.000000        0.000000
# 25%          0.000000           19.664286       42.302567
# 50%         12.691803           19.664286       42.302567
# 75%         12.691803           23.000000       43.000000
# max        175.000000           36.000000      126.000000
# std         17.220910            7.664277       13.398854
#
#        COOLING_DEGREE_DAYS  HEATING_DEGREE_DAYS  MIN_REL_HUMIDITY  \
# count         10216.000000         10216.000000      10216.000000
# mean              0.197948            11.805829         67.023626
# min               0.000000             0.000000         11.000000
# 25%               0.000000             5.300000         67.023626
# 50%               0.000000            11.846119         67.023626
# 75%               0.000000            17.700000         67.023626
# max               7.300000            33.300000        100.000000
# std               0.775527             7.666557         10.378434
#
#        MAX_REL_HUMIDITY                LOCAL_DATE_conv
# count      10216.000000                          10216
# mean          95.079947  2011-04-25 06:44:57.885669376
# min           54.000000            2000-03-01 00:00:00
# 25%           95.079947            2003-04-13 18:00:00
# 50%           95.079947            2011-10-15 12:00:00
# 75%           95.079947            2018-10-23 06:00:00
# max          100.000000            2025-10-20 00:00:00
# std            3.465528                            NaN

# %%
print(df_clean.LOCAL_YEAR.max())
print(df_clean.LOCAL_YEAR.min())
# Out:
# 2025
# 2000

# %%
df_clean.columns
# Out:
# Index(['x', 'y', 'STATION_NAME', 'CLIMATE_IDENTIFIER', 'ID', 'LOCAL_DATE',
#        'PROVINCE_CODE', 'LOCAL_YEAR', 'LOCAL_MONTH', 'LOCAL_DAY',
#        'MEAN_TEMPERATURE', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE',
#        'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW', 'SNOW_ON_GROUND',
#        'DIRECTION_MAX_GUST', 'SPEED_MAX_GUST', 'COOLING_DEGREE_DAYS',
#        'HEATING_DEGREE_DAYS', 'MIN_REL_HUMIDITY', 'MAX_REL_HUMIDITY',
#        'LOCAL_DATE_conv'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df_clean, x='LOCAL_YEAR', y='MEAN_TEMPERATURE')
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')

plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("mean_temp_over_time.png", dpi=300)
plt.show()

# %%
df_clean["STATION_NAME"].unique()
# Out:
# array(["ST JOHN'S WEST CDA CS", 'ST JOHNS WEST CLIMATE', 'LOGY BAY',
#        'SIGNAL HILL'], dtype=object)
