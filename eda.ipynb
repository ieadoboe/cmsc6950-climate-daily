# %% [markdown]
# ## EXPLORATION DATA ANALYSIS (EDA)

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df = pd.read_csv("climate-daily.csv")
df.head()
# Out:
#            x          y STATION_NAME  CLIMATE_IDENTIFIER                ID  \
# 0 -52.733333  47.583333    ST JOHN'S             8403501  8403501.1957.5.1
# 1 -52.733333  47.583333    ST JOHN'S             8403501  8403501.1957.5.2
# 2 -52.733333  47.583333    ST JOHN'S             8403501  8403501.1957.5.3
# 3 -52.733333  47.583333    ST JOHN'S             8403501  8403501.1957.5.4
# 4 -52.733333  47.583333    ST JOHN'S             8403501  8403501.1957.5.5
#
#             LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY  ...  \
# 0  1957-05-01 00:00:00            NL        1957            5          1  ...
# 1  1957-05-02 00:00:00            NL        1957            5          2  ...
# 2  1957-05-03 00:00:00            NL        1957            5          3  ...
# 3  1957-05-04 00:00:00            NL        1957            5          4  ...
# 4  1957-05-05 00:00:00            NL        1957            5          5  ...
#
# ...

# %%
df.tail()
# Out:
#               x          y STATION_NAME  CLIMATE_IDENTIFIER  \
# 6661 -52.733333  47.583333    ST JOHN'S             8403501
# 6662 -52.733333  47.583333    ST JOHN'S             8403501
# 6663 -52.733333  47.583333    ST JOHN'S             8403501
# 6664 -52.733333  47.583333    ST JOHN'S             8403501
# 6665 -52.733333  47.583333    ST JOHN'S             8403501
#
#                      ID           LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  \
# 6661  8403501.1975.7.27  1975-07-27 00:00:00            NL        1975
# 6662  8403501.1975.7.28  1975-07-28 00:00:00            NL        1975
# 6663  8403501.1975.7.29  1975-07-29 00:00:00            NL        1975
# 6664  8403501.1975.7.30  1975-07-30 00:00:00            NL        1975
# 6665  8403501.1975.7.31  1975-07-31 00:00:00            NL        1975
#
#       LOCAL_MONTH  LOCAL_DAY  ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  \
# 6661            7         27  ...             NaN                 NaN
# ...

# %%
print(df.shape)
# Out:
# (6666, 36)

# %%
# dataset info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6666 entries, 0 to 6665
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   x                         6666 non-null   float64
#  1   y                         6666 non-null   float64
#  2   STATION_NAME              6666 non-null   object
#  3   CLIMATE_IDENTIFIER        6666 non-null   int64
#  4   ID                        6666 non-null   object
#  5   LOCAL_DATE                6666 non-null   object
#  6   PROVINCE_CODE             6666 non-null   object
#  7   LOCAL_YEAR                6666 non-null   int64
#  8   LOCAL_MONTH               6666 non-null   int64
#  9   LOCAL_DAY                 6666 non-null   int64
#  10  MEAN_TEMPERATURE          6560 non-null   float64
#  11  MEAN_TEMPERATURE_FLAG     44 non-null     object
#  12  MIN_TEMPERATURE           6563 non-null   float64
# ...

# %%
# unique values
df.nunique()
# Out:
# x                              1
# y                              1
# STATION_NAME                   1
# CLIMATE_IDENTIFIER             1
# ID                          6666
# LOCAL_DATE                  6666
# PROVINCE_CODE                  1
# LOCAL_YEAR                    19
# LOCAL_MONTH                   12
# LOCAL_DAY                     31
# MEAN_TEMPERATURE             215
# MEAN_TEMPERATURE_FLAG          1
# MIN_TEMPERATURE               83
# MIN_TEMPERATURE_FLAG           1
# MAX_TEMPERATURE               84
# MAX_TEMPERATURE_FLAG           1
# TOTAL_PRECIPITATION          194
# TOTAL_PRECIPITATION_FLAG       6
# TOTAL_RAIN                   186
# TOTAL_RAIN_FLAG                6
# TOTAL_SNOW                   100
# TOTAL_SNOW_FLAG                5
# SNOW_ON_GROUND                 0
# SNOW_ON_GROUND_FLAG            0
# DIRECTION_MAX_GUST             0
# DIRECTION_MAX_GUST_FLAG        0
# SPEED_MAX_GUST                 0
# SPEED_MAX_GUST_FLAG            0
# ...

# %%
# Missing values
print(df.isnull().sum())
# Out:
# x                              0
# y                              0
# STATION_NAME                   0
# CLIMATE_IDENTIFIER             0
# ID                             0
# LOCAL_DATE                     0
# PROVINCE_CODE                  0
# LOCAL_YEAR                     0
# LOCAL_MONTH                    0
# LOCAL_DAY                      0
# MEAN_TEMPERATURE             106
# MEAN_TEMPERATURE_FLAG       6622
# MIN_TEMPERATURE              103
# MIN_TEMPERATURE_FLAG        6625
# MAX_TEMPERATURE               64
# MAX_TEMPERATURE_FLAG        6633
# TOTAL_PRECIPITATION           77
# TOTAL_PRECIPITATION_FLAG    5778
# TOTAL_RAIN                    77
# TOTAL_RAIN_FLAG             6035
# TOTAL_SNOW                    51
# TOTAL_SNOW_FLAG             6218
# SNOW_ON_GROUND              6666
# SNOW_ON_GROUND_FLAG         6666
# DIRECTION_MAX_GUST          6666
# DIRECTION_MAX_GUST_FLAG     6666
# SPEED_MAX_GUST              6666
# SPEED_MAX_GUST_FLAG         6666
# ...

# %%
# visualize missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# x                           float64
# y                           float64
# STATION_NAME                 object
# CLIMATE_IDENTIFIER            int64
# ID                           object
# LOCAL_DATE                   object
# PROVINCE_CODE                object
# LOCAL_YEAR                    int64
# LOCAL_MONTH                   int64
# LOCAL_DAY                     int64
# MEAN_TEMPERATURE            float64
# MEAN_TEMPERATURE_FLAG        object
# MIN_TEMPERATURE             float64
# MIN_TEMPERATURE_FLAG         object
# MAX_TEMPERATURE             float64
# MAX_TEMPERATURE_FLAG         object
# TOTAL_PRECIPITATION         float64
# TOTAL_PRECIPITATION_FLAG     object
# TOTAL_RAIN                  float64
# TOTAL_RAIN_FLAG              object
# TOTAL_SNOW                  float64
# TOTAL_SNOW_FLAG              object
# SNOW_ON_GROUND              float64
# SNOW_ON_GROUND_FLAG         float64
# DIRECTION_MAX_GUST          float64
# DIRECTION_MAX_GUST_FLAG     float64
# ...

# %%
df['LOCAL_DATE_conv'] = pd.to_datetime(df['LOCAL_DATE'], errors='coerce')
df[["LOCAL_DATE_conv", "LOCAL_DATE"]]
# Out:
#      LOCAL_DATE_conv           LOCAL_DATE
# 0         1957-05-01  1957-05-01 00:00:00
# 1         1957-05-02  1957-05-02 00:00:00
# 2         1957-05-03  1957-05-03 00:00:00
# 3         1957-05-04  1957-05-04 00:00:00
# 4         1957-05-05  1957-05-05 00:00:00
# ...              ...                  ...
# 6661      1975-07-27  1975-07-27 00:00:00
# 6662      1975-07-28  1975-07-28 00:00:00
# 6663      1975-07-29  1975-07-29 00:00:00
# 6664      1975-07-30  1975-07-30 00:00:00
# 6665      1975-07-31  1975-07-31 00:00:00
#
# [6666 rows x 2 columns]

# %%
df_clean = df.dropna(axis=1, how='all')

# %%
# visualize missing values
sns.heatmap(df_clean.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df_clean.shape
# Out:
# (6666, 27)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6666 entries, 0 to 6665
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   x                         6666 non-null   float64
#  1   y                         6666 non-null   float64
#  2   STATION_NAME              6666 non-null   object
#  3   CLIMATE_IDENTIFIER        6666 non-null   int64
#  4   ID                        6666 non-null   object
#  5   LOCAL_DATE                6666 non-null   object
#  6   PROVINCE_CODE             6666 non-null   object
#  7   LOCAL_YEAR                6666 non-null   int64
#  8   LOCAL_MONTH               6666 non-null   int64
#  9   LOCAL_DAY                 6666 non-null   int64
#  10  MEAN_TEMPERATURE          6560 non-null   float64
#  11  MEAN_TEMPERATURE_FLAG     44 non-null     object
#  12  MIN_TEMPERATURE           6563 non-null   float64
# ...

# %%
# data exploration
print(df_clean.describe())
# Out:
#                  x            y  CLIMATE_IDENTIFIER   LOCAL_YEAR  LOCAL_MONTH  \
# count  6666.000000  6666.000000              6666.0  6666.000000  6666.000000
# mean    -52.733333    47.583333           8403501.0  1965.955446     6.516052
# min     -52.733333    47.583333           8403501.0  1957.000000     1.000000
# 25%     -52.733333    47.583333           8403501.0  1961.000000     4.000000
# 50%     -52.733333    47.583333           8403501.0  1966.000000     7.000000
# 75%     -52.733333    47.583333           8403501.0  1971.000000     9.000000
# max     -52.733333    47.583333           8403501.0  1975.000000    12.000000
# std       0.000000     0.000000                 0.0     5.282759     3.426887
#
#          LOCAL_DAY  MEAN_TEMPERATURE  MIN_TEMPERATURE  MAX_TEMPERATURE  \
# count  6666.000000       6560.000000      6563.000000      6602.000000
# mean     15.730123          5.377485         1.502087         9.294229
# ...

# %%
print(df.LOCAL_YEAR.max())
print(df.LOCAL_YEAR.min())
# Out:
# 1975
# 1957

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='LOCAL_YEAR', y='MEAN_TEMPERATURE')
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/tl/52w5zxkd1zl65mr95qllj_3h0000gn/T/ipykernel_86692/2014921856.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
