# %% [markdown]
# ## EXPLORATION DATA ANALYSIS (EDA)

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df = pd.read_csv("climate-daily-1.csv")
df.head()
# Out:
#            x          y           STATION_NAME  CLIMATE_IDENTIFIER  \
# 0 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 1 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 2 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 3 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
# 4 -52.784722  47.515556  ST JOHN'S WEST CDA CS             8403605
#
#                  ID           LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  \
# 0  8403605.2000.3.1  2000-03-01 00:00:00            NL        2000
# 1  8403605.2000.3.2  2000-03-02 00:00:00            NL        2000
# 2  8403605.2000.3.3  2000-03-03 00:00:00            NL        2000
# 3  8403605.2000.3.4  2000-03-04 00:00:00            NL        2000
# 4  8403605.2000.3.5  2000-03-05 00:00:00            NL        2000
#
#    LOCAL_MONTH  LOCAL_DAY  ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  \
# 0            3          1  ...             NaN                 NaN
# 1            3          2  ...             NaN                 NaN
# 2            3          3  ...             NaN                 NaN
# 3            3          4  ...             NaN                 NaN
# 4            3          5  ...             NaN                 NaN
#
#    COOLING_DEGREE_DAYS COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS  \
# 0                  0.0                      NaN                 16.4
# 1                  0.0                      NaN                 14.2
# 2                  NaN                        M                  NaN
# 3                  NaN                        M                  NaN
# 4                  NaN                        M                  NaN
#
#   HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  \
# 0                      NaN               NaN                   NaN
# 1                      NaN               NaN                   NaN
# 2                        M               NaN                   NaN
# 3                        M               NaN                   NaN
# 4                        M               NaN                   NaN
#
#    MAX_REL_HUMIDITY MAX_REL_HUMIDITY_FLAG
# 0               NaN                   NaN
# 1               NaN                   NaN
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
#
# [5 rows x 36 columns]

# %%
df.tail()
# Out:
#               x          y STATION_NAME  CLIMATE_IDENTIFIER  \
# 9995 -52.683333  47.566667  SIGNAL HILL             8403669
# 9996 -52.683333  47.566667  SIGNAL HILL             8403669
# 9997 -52.683333  47.566667  SIGNAL HILL             8403669
# 9998 -52.683333  47.566667  SIGNAL HILL             8403669
# 9999 -52.683333  47.566667  SIGNAL HILL             8403669
#
#                      ID           LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  \
# 9995  8403669.2000.6.25  2000-06-25 00:00:00            NL        2000
# 9996  8403669.2000.6.26  2000-06-26 00:00:00            NL        2000
# 9997  8403669.2000.6.27  2000-06-27 00:00:00            NL        2000
# 9998  8403669.2000.6.28  2000-06-28 00:00:00            NL        2000
# 9999  8403669.2000.6.29  2000-06-29 00:00:00            NL        2000
#
#       LOCAL_MONTH  LOCAL_DAY  ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  \
# 9995            6         25  ...             NaN                 NaN
# 9996            6         26  ...             NaN                 NaN
# 9997            6         27  ...             NaN                 NaN
# 9998            6         28  ...             NaN                 NaN
# 9999            6         29  ...             NaN                 NaN
#
#       COOLING_DEGREE_DAYS COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS  \
# 9995                  0.0                      NaN                  4.0
# 9996                  0.0                      NaN                  1.2
# 9997                  0.0                      NaN                  6.2
# 9998                  0.0                      NaN                 10.5
# 9999                  0.0                      NaN                  5.0
#
#      HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  \
# 9995                      NaN               NaN                   NaN
# 9996                      NaN               NaN                   NaN
# 9997                      NaN               NaN                   NaN
# 9998                      NaN               NaN                   NaN
# 9999                      NaN               NaN                   NaN
#
#       MAX_REL_HUMIDITY MAX_REL_HUMIDITY_FLAG
# 9995               NaN                   NaN
# 9996               NaN                   NaN
# 9997               NaN                   NaN
# 9998               NaN                   NaN
# 9999               NaN                   NaN
#
# [5 rows x 36 columns]

# %%
print(df.shape)
# Out:
# (10000, 36)

# %%
# dataset info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   x                         10000 non-null  float64
#  1   y                         10000 non-null  float64
#  2   STATION_NAME              10000 non-null  object
#  3   CLIMATE_IDENTIFIER        10000 non-null  int64
#  4   ID                        10000 non-null  object
#  5   LOCAL_DATE                10000 non-null  object
#  6   PROVINCE_CODE             10000 non-null  object
#  7   LOCAL_YEAR                10000 non-null  int64
#  8   LOCAL_MONTH               10000 non-null  int64
#  9   LOCAL_DAY                 10000 non-null  int64
#  10  MEAN_TEMPERATURE          9688 non-null   float64
#  11  MEAN_TEMPERATURE_FLAG     433 non-null    object
#  12  MIN_TEMPERATURE           9735 non-null   float64
#  13  MIN_TEMPERATURE_FLAG      404 non-null    object
#  14  MAX_TEMPERATURE           9774 non-null   float64
#  15  MAX_TEMPERATURE_FLAG      286 non-null    object
#  16  TOTAL_PRECIPITATION       9413 non-null   float64
#  17  TOTAL_PRECIPITATION_FLAG  1347 non-null   object
#  18  TOTAL_RAIN                1687 non-null   float64
#  19  TOTAL_RAIN_FLAG           3042 non-null   object
#  20  TOTAL_SNOW                1713 non-null   float64
#  21  TOTAL_SNOW_FLAG           3013 non-null   object
#  22  SNOW_ON_GROUND            5185 non-null   float64
#  23  SNOW_ON_GROUND_FLAG       518 non-null    object
#  24  DIRECTION_MAX_GUST        4900 non-null   float64
#  25  DIRECTION_MAX_GUST_FLAG   126 non-null    object
#  26  SPEED_MAX_GUST            4908 non-null   float64
#  27  SPEED_MAX_GUST_FLAG       120 non-null    object
#  28  COOLING_DEGREE_DAYS       9688 non-null   float64
#  29  COOLING_DEGREE_DAYS_FLAG  433 non-null    object
#  30  HEATING_DEGREE_DAYS       9688 non-null   float64
#  31  HEATING_DEGREE_DAYS_FLAG  433 non-null    object
#  32  MIN_REL_HUMIDITY          3767 non-null   float64
#  33  MIN_REL_HUMIDITY_FLAG     112 non-null    object
#  34  MAX_REL_HUMIDITY          3765 non-null   float64
#  35  MAX_REL_HUMIDITY_FLAG     114 non-null    object
# dtypes: float64(15), int64(4), object(17)
# memory usage: 2.7+ MB
# None

# %%
# unique values
df.nunique()
# Out:
# x                               4
# y                               4
# STATION_NAME                    4
# CLIMATE_IDENTIFIER              4
# ID                          10000
# LOCAL_DATE                   8234
# PROVINCE_CODE                   1
# LOCAL_YEAR                     24
# LOCAL_MONTH                    12
# LOCAL_DAY                      31
# MEAN_TEMPERATURE              390
# MEAN_TEMPERATURE_FLAG           2
# MIN_TEMPERATURE               399
# MIN_TEMPERATURE_FLAG            4
# MAX_TEMPERATURE               417
# MAX_TEMPERATURE_FLAG            2
# TOTAL_PRECIPITATION           412
# TOTAL_PRECIPITATION_FLAG        7
# TOTAL_RAIN                     81
# TOTAL_RAIN_FLAG                 7
# TOTAL_SNOW                     16
# TOTAL_SNOW_FLAG                 7
# SNOW_ON_GROUND                135
# SNOW_ON_GROUND_FLAG             3
# DIRECTION_MAX_GUST             37
# DIRECTION_MAX_GUST_FLAG         2
# SPEED_MAX_GUST                 69
# SPEED_MAX_GUST_FLAG             2
# COOLING_DEGREE_DAYS            72
# COOLING_DEGREE_DAYS_FLAG        2
# HEATING_DEGREE_DAYS           319
# HEATING_DEGREE_DAYS_FLAG        2
# MIN_REL_HUMIDITY               83
# MIN_REL_HUMIDITY_FLAG           1
# MAX_REL_HUMIDITY               38
# MAX_REL_HUMIDITY_FLAG           1
# dtype: int64

# %%
# Missing values
print(df.isnull().sum())
# Out:
# x                              0
# y                              0
# STATION_NAME                   0
# CLIMATE_IDENTIFIER             0
# ID                             0
# LOCAL_DATE                     0
# PROVINCE_CODE                  0
# LOCAL_YEAR                     0
# LOCAL_MONTH                    0
# LOCAL_DAY                      0
# MEAN_TEMPERATURE             312
# MEAN_TEMPERATURE_FLAG       9567
# MIN_TEMPERATURE              265
# MIN_TEMPERATURE_FLAG        9596
# MAX_TEMPERATURE              226
# MAX_TEMPERATURE_FLAG        9714
# TOTAL_PRECIPITATION          587
# TOTAL_PRECIPITATION_FLAG    8653
# TOTAL_RAIN                  8313
# TOTAL_RAIN_FLAG             6958
# TOTAL_SNOW                  8287
# TOTAL_SNOW_FLAG             6987
# SNOW_ON_GROUND              4815
# SNOW_ON_GROUND_FLAG         9482
# DIRECTION_MAX_GUST          5100
# DIRECTION_MAX_GUST_FLAG     9874
# SPEED_MAX_GUST              5092
# SPEED_MAX_GUST_FLAG         9880
# COOLING_DEGREE_DAYS          312
# COOLING_DEGREE_DAYS_FLAG    9567
# HEATING_DEGREE_DAYS          312
# HEATING_DEGREE_DAYS_FLAG    9567
# MIN_REL_HUMIDITY            6233
# MIN_REL_HUMIDITY_FLAG       9888
# MAX_REL_HUMIDITY            6235
# MAX_REL_HUMIDITY_FLAG       9886
# dtype: int64

# %%
# visualize missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# x                           float64
# y                           float64
# STATION_NAME                 object
# CLIMATE_IDENTIFIER            int64
# ID                           object
# LOCAL_DATE                   object
# PROVINCE_CODE                object
# LOCAL_YEAR                    int64
# LOCAL_MONTH                   int64
# LOCAL_DAY                     int64
# MEAN_TEMPERATURE            float64
# MEAN_TEMPERATURE_FLAG        object
# MIN_TEMPERATURE             float64
# MIN_TEMPERATURE_FLAG         object
# MAX_TEMPERATURE             float64
# MAX_TEMPERATURE_FLAG         object
# TOTAL_PRECIPITATION         float64
# TOTAL_PRECIPITATION_FLAG     object
# TOTAL_RAIN                  float64
# TOTAL_RAIN_FLAG              object
# TOTAL_SNOW                  float64
# TOTAL_SNOW_FLAG              object
# SNOW_ON_GROUND              float64
# SNOW_ON_GROUND_FLAG          object
# DIRECTION_MAX_GUST          float64
# DIRECTION_MAX_GUST_FLAG      object
# SPEED_MAX_GUST              float64
# SPEED_MAX_GUST_FLAG          object
# COOLING_DEGREE_DAYS         float64
# COOLING_DEGREE_DAYS_FLAG     object
# HEATING_DEGREE_DAYS         float64
# HEATING_DEGREE_DAYS_FLAG     object
# MIN_REL_HUMIDITY            float64
# MIN_REL_HUMIDITY_FLAG        object
# MAX_REL_HUMIDITY            float64
# MAX_REL_HUMIDITY_FLAG        object
# dtype: object

# %%
df['LOCAL_DATE_conv'] = pd.to_datetime(df['LOCAL_DATE'], errors='coerce')
df[["LOCAL_DATE_conv", "LOCAL_DATE"]]
# Out:
#      LOCAL_DATE_conv           LOCAL_DATE
# 0         2000-03-01  2000-03-01 00:00:00
# 1         2000-03-02  2000-03-02 00:00:00
# 2         2000-03-03  2000-03-03 00:00:00
# 3         2000-03-04  2000-03-04 00:00:00
# 4         2000-03-05  2000-03-05 00:00:00
# ...              ...                  ...
# 9995      2000-06-25  2000-06-25 00:00:00
# 9996      2000-06-26  2000-06-26 00:00:00
# 9997      2000-06-27  2000-06-27 00:00:00
# 9998      2000-06-28  2000-06-28 00:00:00
# 9999      2000-06-29  2000-06-29 00:00:00
#
# [10000 rows x 2 columns]

# %%
df_clean = df.dropna(axis=1, how='all') # drop all nan columns
df_clean = df_clean.loc[:, ~df_clean.columns.str.endswith('_FLAG')] # drop all columns that end in _FLAG

# %%
# visualize missing values
sns.heatmap(df_clean.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df_clean = df_clean.fillna(df.mean(numeric_only=True))
df_clean.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df_clean.shape
# Out:
# (10000, 24)

# %%
sns.heatmap(df_clean.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   x                    10000 non-null  float64
#  1   y                    10000 non-null  float64
#  2   STATION_NAME         10000 non-null  object
#  3   CLIMATE_IDENTIFIER   10000 non-null  int64
#  4   ID                   10000 non-null  object
#  5   LOCAL_DATE           10000 non-null  object
#  6   PROVINCE_CODE        10000 non-null  object
#  7   LOCAL_YEAR           10000 non-null  int64
#  8   LOCAL_MONTH          10000 non-null  int64
#  9   LOCAL_DAY            10000 non-null  int64
#  10  MEAN_TEMPERATURE     10000 non-null  float64
#  11  MIN_TEMPERATURE      10000 non-null  float64
#  12  MAX_TEMPERATURE      10000 non-null  float64
#  13  TOTAL_PRECIPITATION  10000 non-null  float64
#  14  TOTAL_RAIN           10000 non-null  float64
#  15  TOTAL_SNOW           10000 non-null  float64
#  16  SNOW_ON_GROUND       10000 non-null  float64
#  17  DIRECTION_MAX_GUST   10000 non-null  float64
#  18  SPEED_MAX_GUST       10000 non-null  float64
#  19  COOLING_DEGREE_DAYS  10000 non-null  float64
#  20  HEATING_DEGREE_DAYS  10000 non-null  float64
#  21  MIN_REL_HUMIDITY     10000 non-null  float64
#  22  MAX_REL_HUMIDITY     10000 non-null  float64
#  23  LOCAL_DATE_conv      10000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), int64(4), object(4)
# memory usage: 1.8+ MB

# %%
# data exploration
print(df_clean.describe())
# Out:
#                   x             y  CLIMATE_IDENTIFIER    LOCAL_YEAR  \
# count  10000.000000  10000.000000        1.000000e+04  10000.000000
# mean     -52.762900     47.532825        8.403434e+06   2011.042000
# min      -52.784722     47.513356        8.402568e+06   2000.000000
# 25%      -52.784722     47.513356        8.403603e+06   2003.000000
# 50%      -52.783339     47.513356        8.403603e+06   2012.000000
# 75%      -52.783339     47.515556        8.403605e+06   2018.000000
# max      -52.664167     47.624167        8.403669e+06   2025.000000
# std        0.045169      0.040948        3.843853e+02      8.234052
#
#         LOCAL_MONTH     LOCAL_DAY  MEAN_TEMPERATURE  MIN_TEMPERATURE  \
# count  10000.000000  10000.000000      10000.000000     10000.000000
# mean       6.513300     15.732500          6.353365         2.439866
# min        1.000000      1.000000        -15.300000       -20.600000
# 25%        4.000000      8.000000          0.200000        -2.600000
# 50%        6.000000     16.000000          6.200000         2.100000
# 75%        9.000000     23.000000         12.600000         8.100000
# max       12.000000     31.000000         25.300000        22.300000
# std        3.401879      8.802153          7.990518         7.641986
#
#        MAX_TEMPERATURE  TOTAL_PRECIPITATION    TOTAL_RAIN    TOTAL_SNOW  \
# count     10000.000000         10000.000000  10000.000000  10000.000000
# mean         10.258461             3.691151      2.766034      0.441623
# min         -13.000000             0.000000      0.000000      0.000000
# 25%           3.000000             0.000000      2.766034      0.441623
# 50%          10.000000             0.500000      2.766034      0.441623
# 75%          17.200000             3.691151      2.766034      0.441623
# max          31.800000           106.300000     70.000000     28.000000
# std           8.791610             7.432514      2.695105      0.830714
#
#        SNOW_ON_GROUND  DIRECTION_MAX_GUST  SPEED_MAX_GUST  \
# count    10000.000000        10000.000000    10000.000000
# mean        12.691803           19.664286       42.302567
# min          0.000000            0.000000        0.000000
# 25%          0.000000           19.664286       42.302567
# 50%         12.691803           19.664286       42.302567
# 75%         12.691803           23.000000       43.000000
# max        175.000000           36.000000      126.000000
# std         17.338743            7.746617       13.542803
#
#        COOLING_DEGREE_DAYS  HEATING_DEGREE_DAYS  MIN_REL_HUMIDITY  \
# count         10000.000000         10000.000000      10000.000000
# mean              0.199484            11.846119         67.023626
# min               0.000000             0.000000         11.000000
# 25%               0.000000             5.400000         67.023626
# 50%               0.000000            11.846119         67.023626
# 75%               0.000000            17.800000         67.023626
# max               7.300000            33.300000        100.000000
# std               0.779980             7.659033         10.489933
#
#        MAX_REL_HUMIDITY             LOCAL_DATE_conv
# count      10000.000000                       10000
# mean          95.079947  2011-07-17 07:21:56.160000
# min           54.000000         2000-03-01 00:00:00
# 25%           95.079947         2003-07-03 18:00:00
# 50%           95.079947         2012-01-31 12:00:00
# 75%           95.079947         2018-12-16 06:00:00
# max          100.000000         2025-10-20 00:00:00
# std            3.502759                         NaN

# %%
print(df_clean.LOCAL_YEAR.max())
print(df_clean.LOCAL_YEAR.min())
# Out:
# 2025
# 2000

# %%
df_clean.columns
# Out:
# Index(['x', 'y', 'STATION_NAME', 'CLIMATE_IDENTIFIER', 'ID', 'LOCAL_DATE',
#        'PROVINCE_CODE', 'LOCAL_YEAR', 'LOCAL_MONTH', 'LOCAL_DAY',
#        'MEAN_TEMPERATURE', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE',
#        'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW', 'SNOW_ON_GROUND',
#        'DIRECTION_MAX_GUST', 'SPEED_MAX_GUST', 'COOLING_DEGREE_DAYS',
#        'HEATING_DEGREE_DAYS', 'MIN_REL_HUMIDITY', 'MAX_REL_HUMIDITY',
#        'LOCAL_DATE_conv'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df_clean, x='LOCAL_YEAR', y='MEAN_TEMPERATURE')
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')

plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("mean_temp_over_time.png", dpi=300)
plt.show()

# %%
df_clean["STATION_NAME"].unique()
# Out:
# array(["ST JOHN'S WEST CDA CS", 'ST JOHNS WEST CLIMATE', 'LOGY BAY',
#        'SIGNAL HILL'], dtype=object)
